# %% [markdown]
# # Pandas

# %% [markdown]
# Do Conjunto de aulas: **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>

# %% [markdown]
# ## Importação do Pandas

# %%
import pandas as pd

# %% [markdown]
# ## 1.1 Importando o Dataset

# %%
df = pd.read_csv('../datasets/GasPricesinBrazil_2004-2019.csv', sep=';')

# %%
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  str
#  2   DATA FINAL                     106823 non-null  str
#  3   REGIÃO                         106823 non-null  str
#  4   ESTADO                         106823 non-null  str
#  5   PRODUTO                        106823 non-null  str
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  str
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
df.shape
# Out:
# (106823, 21)

# %%
print(f'O DataFrame possui {df.shape[0]} linhas e {df.shape[1]} colunas')
# Out:
# O DataFrame possui 106823 linhas e 21 colunas

# %% [markdown]
# ## Criando um DataFrame

# %%
personagens_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70.5, 15.2, 60.1],
    'eh jedi': [True, True, False]
})

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %%
personagens_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      str
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      float64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), str(1)
# memory usage: 207.0 bytes

# %% [markdown]
# ## Renomeando Colunas de um DataFrame

# %% [markdown]
# ### Renomear com df.rename({'old_name': 'new_name'})

# %%
personagens_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='str')

# %%
type(personagens_df.columns)
# Out:
# pandas.Index

# %%
list(personagens_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %%
personagens_df_renomeado = personagens_df.rename(columns={
    'name': 'Nome Completo',
    'idade': 'Idade'
})

# %%
personagens_df_renomeado
# Out:
#              nome  Idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %% [markdown]
# ### Para renomear o mesmo df

# %%
personagens_df.rename(columns={
    'name': 'Nome Completo',
    'idade': 'Idade'
}, inplace=True)

# %%
personagens_df
# Out:
#              nome  Idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %%
personagens_df.columns
# Out:
# Index(['nome', 'Idade', 'peso', 'eh jedi'], dtype='str')

# %%
personagens_df.columns = ['NOME', 'IDADE', 'PESO', 'EH_JEDI']

# %%
personagens_df
# Out:
#              NOME  IDADE  PESO  EH_JEDI
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %% [markdown]
# ## 1.3 Series

# %%
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
df['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: str

# %%
df.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: str

# %%
type(df['ESTADO'])
# Out:
# pandas.Series

# %%
df.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %%
type(df.iloc[1])
# Out:
# pandas.Series

# %% [markdown]
# ## Criando uma Series

# %%
pd.Series([5.5, 6.0, 9.5])
# Out:
# 0    5.5
# 1    6.0
# 2    9.5
# dtype: float64

# %%
pd.Series([3.2, 6.3, 8.5], index=['prova 1', 'prova 2', 'projeto'], name='Notas dos Luke Skywalker')
# Out:
# prova 1    3.2
# prova 2    6.3
# projeto    8.5
# Name: Notas dos Luke Skywalker, dtype: float64

# %%
produto_view = df['PRODUTO']
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str

# %%
produto_copy_bkp = df['PRODUTO'].copy()
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str

# %%
df['PRODUTO'] = 'Combustível'

# %%
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustível                           127              R$/l
# 1  Combustível                           387              R$/l
# 2  Combustível                           192              R$/l
# 3  Combustível                           162              R$/l
# 4  Combustível                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str

# %%
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str

# %% [markdown]
# ## Atribuindo listas ou series

# %%
nrows, ncols = df.shape
nrows, ncols
# Out:
# (106823, 21)

# %%
novos_produtos = [f'Produto {i}' for i in range(nrows)]
len(novos_produtos)
# Out:
# 106823

# %%
df['PRODUTO'] = novos_produtos

# %%
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO         PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL       Produto 0                           127
# 1                     GOIAS       Produto 1                           387
# ...

# %%
print(produto_view)
print('\n')
print(produto_copy_bkp)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str

# %%
df['PRODUTO'] = produto_copy_bkp

# %%
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
df['coluna sem sentido'] = 'DEFAULT'
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
df['coluna a partir de lista'] = range(df.shape[0])

# %%
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
# df['nao funciona'] = [1, 2, 3]

# %%
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# ...

# %%
df['PREÇO MÉDIO REVENDA (dólares)'] = df['PREÇO MÉDIO REVENDA'] * 6.0

# %%
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %% [markdown]
# ### Índices

# %%
df.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation4', 'Switch'], dtype='str')

# %% [markdown]
# ### Seleção Baseada em Índices

# %%
df.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %%
df.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# ...

# %%
df.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# ...

# %%
df.iloc[[1, 5, 10, 15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# ...

# %%
df.iloc[[5, 1, 15, 10]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                 1.383                  0.132  ...                     0.957
# 1                 1.162                  0.114  ...                     0.763
# ...

# %%
df.iloc[1, 4]
# Out:
# 'GOIAS'

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao.iloc[0, 1]
# Out:
# np.int64(131)

# %%
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# pesquisa_de_satisfacao.iloc['XboxOne']

# %%
# pesquisa_de_satisfacao.loc[0]

# %% [markdown]
# ### Seleção Baseadas em Rótulos

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
# Out:
# np.int64(2)

# %%
pesquisa_de_satisfacao.loc[['XboxOne', 'Switch']]
# Out:
#          bom  ruim  pessimo
# XboxOne   50   131       30
# Switch   100    30        1

# %%
pesquisa_de_satisfacao[['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %% [markdown]
# #### Observação
# Índices Numéricos possuem rótulos que correspondem aos seus valores numéricos

# %%
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
df.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %%
df.loc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %% [markdown]
# ## Selecionando uma ou mais colunas

# %%
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
df['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
df.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
df.loc[:, 'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
df['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 106818    2019-06-23
# 106819    2019-06-23
# 106820    2019-06-23
# 106821    2019-06-23
# 106822    2019-06-23
# Name: DATA INICIAL, Length: 106823, dtype: object

# %%
df[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %% [markdown]
# ## Removendo uma coluna do DataFrame

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
del df['coluna sem sentido']
del df['coluna a partir de lista']
del df['PREÇO MÉDIO REVENDA (dólares)']

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# ## Salvando um DataFrame

# %%
df.to_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv', index=False)

# %% [markdown]
# ## Seleção Condicional: Filtrando Amostras

# %%
df = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv')

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
df['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# ### Selecionando apenas os preços dos postos de São Paulo

# %% [markdown]
# #### Alternativa 1: Seleção Condicional

# %%
df['ESTADO'] == 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
selecao = df['ESTADO'] == 'SAO PAULO'

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
selecao.shape
# Out:
# (106823,)

# %%
df.shape
# Out:
# (106823, 20)

# %%
df[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
df.loc[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# #### Alternativa 2: Utilizando método `query`

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
df.query('ESTADO == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
postos_sp = df.query('ESTADO == "SAO PAULO"')

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
type(postos_sp)
# Out:
# pandas.core.frame.DataFrame

# %%
postos_sp.shape
# Out:
# (4263, 20)

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# ### Resetando Índices

# %%
postos_sp.reset_index()
# Out:
#        index DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0         23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1         50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2         77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3        104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4        131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...      ...          ...         ...      ...        ...               ...
# 4258  106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259  106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260  106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261  106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262  106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
# ...

# %%
postos_sp.reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
postos_sp.reset_index(drop=True, inplace=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
postos_sp = df.query('ESTADO == "SAO PAULO"').reset_index(drop=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %% [markdown]
# ### Selecionando postos do Rio de Janeiro com preços acima de 2 reais

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
df['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
df['PREÇO MÉDIO REVENDA'] > 2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
selecao = (df['ESTADO'] == 'RIO DE JANEIRO') & (df['PREÇO MÉDIO REVENDA'] > 2.0)
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %%
df[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %%
# Não funciona
# df.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %%
df.query('ESTADO == "RIO DE JANEIRO" or ESTADO == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
# ...

# %%
selecao_1 = df['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = df[selecao_1]
postos_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 103      2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 130      2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %%
selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2
selecao_2
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 106718     True
# 106745     True
# 106772     True
# 106799     True
# 106817     True
# Name: PREÇO MÉDIO REVENDA, Length: 4263, dtype: bool

# %%
postos_rj_preco_maior_que_2 = postos_rj[selecao_2]
postos_rj_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %% [markdown]
# ### Selecionando postos de São Paulo ou do Rio de Janeiro com gasolina comum acima de 2 reais

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
selecao_1 = (df['ESTADO'] == 'SAO PAULO') | (df['ESTADO'] == 'RIO DE JANEIRO')
selecao_2 = (df['PRODUTO'] == 'GASOLINA COMUM')
selecao_3 = (df['PREÇO MÉDIO REVENDA'] > 2)

selecao_final = selecao_1 & selecao_2 & selecao_3

# %%
selecao_final
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %%
df_filtrado = df[selecao_final]
df_filtrado
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
print(df_filtrado['ESTADO'].unique())
print(df_filtrado['PRODUTO'].unique())
# Out:
# ['RIO DE JANEIRO' 'SAO PAULO']
# ['GASOLINA COMUM']

# %%
selecao_1 = (df['ESTADO'] == 'SAO PAULO') | (df['ESTADO'] == 'RIO DE JANEIRO')
postos_sp_rj = df[selecao_1]

postos_sp_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
# ...

# %%
selecao_2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')
postos_sp_rj_gasolina = postos_sp_rj[selecao_2]

postos_sp_rj_gasolina
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12087    2004-05-09  2004-05-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12114    2004-05-16  2004-05-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
selecao_3 = (postos_sp_rj_gasolina['PREÇO MÉDIO REVENDA'] > 2)

postos_sp_rj_gasolina_preco_maior_que_2 = postos_sp_rj_gasolina[selecao_3]
postos_sp_rj_gasolina_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# ### Selecionando Registros dos anos de 2008, 2010 e 2012

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# #### Alternativa 1

# %%
selecao = (df['ANO'] == 2008) | (df['ANO'] == 2010) | (df['ANO'] == 2012)
df[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# #### Alternativa 2

# %%
lista_de_anos = [2008, 2010, 2012]

# %%
selecao = df['ANO'].isin(lista_de_anos)
df[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# #### Alternativa 3

# %%
lista_de_anos
# Out:
# [2008, 2010, 2012]

# %%
df.query('ANO in @lista_de_anos')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# ### Iterando com DataFrames

# %%
df.head(10)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# ...

# %%
for index, row in df.head(10).iterrows():
    print(f'indice {index} ==> {row["ESTADO"]}')
# Out:
# indice 0 ==> DISTRITO FEDERAL
# indice 1 ==> GOIAS
# indice 2 ==> MATO GROSSO
# indice 3 ==> MATO GROSSO DO SUL
# indice 4 ==> ALAGOAS
# indice 5 ==> BAHIA
# indice 6 ==> CEARA
# indice 7 ==> MARANHAO
# indice 8 ==> PARAIBA
# indice 9 ==> PERNAMBUCO

# %% [markdown]
# ## 2. Preparação dos dados
# ---

# %%
df
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
# ...

# %%
df_pre = df.copy()

# %%
df_pre['DATA INICIAL'] = pd.to_datetime(df_pre['DATA INICIAL'])
df_pre['DATA FINAL'] = pd.to_datetime(df_pre['DATA FINAL'])

# %%
df_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
# convertendo atributos/colunas para 'numeric'
for atributo in ['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
    # converte a coluna (de valores string) para um tipo numérico
    # Em caso de erro na conversão (p. ex., uma string que não representa um número), um valor vazio (null / nan) será
    # atribuído no lugar
    df_pre[atributo] = pd.to_numeric(df_pre[atributo], errors='coerce')

# %%
df_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %% [markdown]
# ## Limpeza dos Dados

# %%
mask = df_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
df_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
df[mask]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25  2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09  2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23  2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26  2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27  2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106664   2019-06-16  2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16  2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23  2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23  2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23  2019-06-29      SUL          PARANA               GNV
#
# ...

# %%
df_pre_fill = df_pre.fillna(0)
df_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
df_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
df_pre_fill = df_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO': 10,
    'DESVIO PADRÃO DISTRIBUIÇÃO': 20,
    'PREÇO MÍNIMO DISTRIBUIÇÃO': 30,
    'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio'
})

# %%
df_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
df_pre.dropna(inplace=True)

# %%
df_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103392 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  datetime64[ns]
#  1   DATA FINAL                     103392 non-null  datetime64[ns]
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
# ...

# %%
df_pre.to_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv', index=False)

# %% [markdown]
# ## Estatísticas Descritivas

# %%
df_final = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv')

# %%
df_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
df_final.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# ...

# %%
df_final['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
df_final.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = df_final.describe()
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# ...

# %%
stats[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %%
df_final[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %%
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# ...

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
#       NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# min                       1.000000             0.766000
# max                    4167.000000            99.357000
# mean                    240.511935            10.784472
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# min                0.000000              0.590000              0.999000
# max               10.748000             90.000000            120.000000
# mean               0.652589              9.334931             12.458686
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# min               0.001000                  0.000000
# max              36.847000                  0.262000
# mean              2.225151                  0.045749
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# min                   0.506000                    0.000000
# max                  83.137000                   18.385000
# ...

# %%
stats.loc[['min', 'max', 'mean'], 'PREÇO MÉDIO REVENDA']
# Out:
# min      0.766000
# max     99.357000
# mean    10.784472
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats.loc[['min', 'max', 'mean'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#       PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# min              0.766000                  0.506000
# max             99.357000                 83.137000
# mean            10.784472                  8.559322

# %%
df_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# ### Qual o menor preço mínimo de revenda?

# %%
df_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# np.float64(0.59)

# %% [markdown]
# ### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
mean = df_final['PREÇO MÍNIMO REVENDA'].mean()
std = df_final['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços mínimos de revenda é {mean:.2f} +- {std:.2f}')
# Out:
# A média dos preços mínimos de revenda é 9.33 +- 15.02

# %% [markdown]
# ### Quais são os estados considerados?

# %%
df_final['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
df_final['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
sorted(df_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# ### Quantos registros cada estado possui?

# %%
df_final['ESTADO'].value_counts()
# Out:
# ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: count, dtype: int64

# %%
df_final['ESTADO'].value_counts().to_frame()
# Out:
#                      count
# ESTADO
# BAHIA                 4263
# RIO DE JANEIRO        4262
# SAO PAULO             4261
# RIO GRANDE DO SUL     4249
# PARAIBA               4240
# PERNAMBUCO            4236
# SERGIPE               4202
# SANTA CATARINA        4164
# MINAS GERAIS          4142
# ESPIRITO SANTO        4079
# MATO GROSSO DO SUL    4076
# ALAGOAS               4020
# RIO GRANDE DO NORTE   3999
# CEARA                 3964
# PARANA                3902
# AMAZONAS              3713
# MATO GROSSO           3703
# PARA                  3477
# MARANHAO              3470
# ACRE                  3463
# RORAIMA               3457
# TOCANTINS             3453
# GOIAS                 3449
# RONDONIA              3441
# PIAUI                 3394
# DISTRITO FEDERAL      3317
# AMAPA                 2996

# %% [markdown]
# ## Executando Funções para cada item de um DataFrame ou Series

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
def nossa_soma(series):
    return series.sum()

# %%
df['SOMA(A, B, C)'] = df.apply(nossa_soma, axis=1)
df
# Out:
#          A   B    C  SOMA(A, B, C)
# Linha 1  1  10  100            111
# Linha 2  2  20  200            222
# Linha 3  3  30  300            333
# Linha 4  4  40  400            444

# %%
df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)
df
# Out:
#           A    B     C  SOMA(A, B, C)
# Linha 1   1   10   100            111
# Linha 2   2   20   200            222
# Linha 3   3   30   300            333
# Linha 4   4   40   400            444
# Linha 5  10  100  1000           1110

# %%
df['MEDIA(A, B, C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)
# Linha 1   1   10   100            111            37.0
# Linha 2   2   20   200            222            74.0
# Linha 3   3   30   300            333           111.0
# Linha 4   4   40   400            444           148.0
# Linha 5  10  100  1000           1110           370.0

# %%
df['C * 2'] = df['C'].apply(lambda x: x * 2)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)  C * 2
# Linha 1   1   10   100            111            37.0    200
# Linha 2   2   20   200            222            74.0    400
# Linha 3   3   30   300            333           111.0    600
# Linha 4   4   40   400            444           148.0    800
# Linha 5  10  100  1000           1110           370.0   2000

# %%
df['A * 2'] = df['A'] * 2
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)  C * 2  A * 2
# Linha 1   1   10   100            111            37.0    200      2
# Linha 2   2   20   200            222            74.0    400      4
# Linha 3   3   30   300            333           111.0    600      6
# Linha 4   4   40   400            444           148.0    800      8
# Linha 5  10  100  1000           1110           370.0   2000     20

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
df.applymap(lambda x: x ** 2)
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_31776\1536622702.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x ** 2)
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
nomes = pd.Series(['João', 'Maria', 'Alice', 'Pedro'])
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %%
nomes.map(lambda x: x.upper())
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object

# %%
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %%
nomes.str.upper()
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object

# %% [markdown]
# ## Agrupamento

# %%
df_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
grupos = df_final.groupby('REGIÃO')
grupos

# %%
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14,
# ...

# %%
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 103363, 103364, 103383],
#        shape=(14545,)),
#  'NORDESTE': array([     4,      5,      6, ..., 103385, 103387, 103391],
#        shape=(35788,)),
#  'NORTE': array([    13,     14,     15, ..., 103374, 103375, 103379],
#        shape=(24000,)),
#  'SUDESTE': array([    20,     21,     22, ..., 103377, 103386, 103390],
#        shape=(16744,)),
#  'SUL': array([    24,     25,     26, ..., 103376, 103388, 103389],
#        shape=(12315,))}

# %%
grupos.get_group('CENTRO OESTE')
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 27       2004-05-16  2004-05-22  CENTRO OESTE    DISTRITO FEDERAL
# ...             ...         ...           ...                 ...
# 103359   2019-06-23  2019-06-29  CENTRO OESTE    DISTRITO FEDERAL
# 103361   2019-06-23  2019-06-29  CENTRO OESTE               GOIAS
# 103363   2019-06-23  2019-06-29  CENTRO OESTE         MATO GROSSO
# 103364   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
# 103383   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
grupos.describe()
# Out:
#              NÚMERO DE POSTOS PESQUISADOS                                      \
#                                     count        mean         std  min    25%
# REGIÃO
# CENTRO OESTE                      14545.0  144.898453  105.699340  1.0   80.0
# NORDESTE                          35788.0  124.721834  113.110808  1.0   41.0
# NORTE                             24000.0   67.835958   52.961342  1.0   31.0
# SUDESTE                           16744.0  726.068024  787.588935  1.0  168.0
# SUL                               12315.0  366.266423  233.276285  1.0  188.0
#
#                                    PREÇO MÉDIO REVENDA             ...   MÊS  \
#                 50%    75%     max               count       mean  ...   75%
# REGIÃO                                                             ...
# CENTRO OESTE  128.0  192.0   766.0             14545.0  12.299706  ...   9.0
# NORDESTE       95.0  169.0   625.0             35788.0   9.558746  ...  10.0
# ...

# %%
# grupos.mean()

# %%
grupos.min()
# Out:
#              DATA INICIAL  DATA FINAL            ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09  2004-05-15  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE       2004-05-09  2004-05-15           ALAGOAS  ETANOL HIDRATADO
# NORTE          2004-05-09  2004-05-15              ACRE  ETANOL HIDRATADO
# SUDESTE        2004-05-09  2004-05-15    ESPIRITO SANTO  ETANOL HIDRATADO
# SUL            2004-05-09  2004-05-15            PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# ...

# %%
df_final.groupby('REGIÃO').min()
# Out:
#              DATA INICIAL  DATA FINAL            ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09  2004-05-15  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE       2004-05-09  2004-05-15           ALAGOAS  ETANOL HIDRATADO
# NORTE          2004-05-09  2004-05-15              ACRE  ETANOL HIDRATADO
# SUDESTE        2004-05-09  2004-05-15    ESPIRITO SANTO  ETANOL HIDRATADO
# SUL            2004-05-09  2004-05-15            PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# ...

# %%
df_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# ### Qual é o preço médio de cada Combustível para cada Região?

# %%
grupos = df_final.groupby(['REGIÃO', 'PRODUTO'])
grupos

# %%
grupos.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA COMUM'): [11980, 11981, 11982, 11983, 12007, 12008, 12009, 12010, 12034, 12035, 12036, 12037, 12061, 12062, 12063, 12064, 12088, 12089, 12090, 12091, 12115, 12116, 12117, 12118, 12142, 12143, 12144, 12145, 12169, 12170, 12171, 12172, 12196, 12197, 12198, 12199, 12223, 12224, 12225, 12226, 12250, 12251, 12252, 12253, 12277, 12278, 12279, 12280, 12304, 12305, 12306, 12307, 12331, 12332, 12333, 12334, 12358, 12359, 12360, 12361, 12385, 12386, 1
# ...

# %%
# grupos.mean()

# %%
grupos['PREÇO MÉDIO REVENDA'].mean()
# Out:
# REGIÃO        PRODUTO
# CENTRO OESTE  ETANOL HIDRATADO     2.135670
#               GASOLINA COMUM       3.077476
#               GLP                 48.176747
#               GNV                  1.856312
#               ÓLEO DIESEL          2.481286
#               ÓLEO DIESEL S10      3.294752
# NORDESTE      ETANOL HIDRATADO     2.320266
#               GASOLINA COMUM       3.001887
#               GLP                 41.966090
#               GNV                  1.881722
#               ÓLEO DIESEL          2.346950
#               ÓLEO DIESEL S10      3.041966
# NORTE         ETANOL HIDRATADO     2.511624
#               GASOLINA COMUM       3.149501
#               GLP                 47.065572
#               GNV                  2.084399
#               ÓLEO DIESEL          2.571048
#               ÓLEO DIESEL S10      3.316231
# SUDESTE       ETANOL HIDRATADO     2.163621
#               GASOLINA COMUM       3.000565
#               GLP                 42.081544
# ...

# %%
grupos['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                                 count       mean        std     min       25%  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  3122.0   2.135670   0.561465   1.162   1.71400
#              GASOLINA COMUM    3134.0   3.077476   0.615290   1.936   2.66725
#              GLP               3098.0  48.176747  15.204045  28.791  37.33300
#              GNV                847.0   1.856312   0.423861   1.097   1.56900
#              ÓLEO DIESEL       3134.0   2.481286   0.626930   1.435   2.03300
#              ÓLEO DIESEL S10   1210.0   3.294752   0.421234   2.305   2.92425
# NORDESTE     ETANOL HIDRATADO  7046.0   2.320266   0.604374   1.181   1.82500
#              GASOLINA COMUM    7063.0   3.001887   0.640696   1.949   2.58400
#              GLP               6410.0  41.966090  12.063743  28.367  33.22875
#              GNV               5176.0   1.881722   0.522996   0.975   1.59600
#              ÓLEO DIESEL       7061.0   2.346950   0.605705   1.313   1.90000
# ...

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [None, None, None]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum, min])
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_31776\2309299637.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.agg([sum, min])
# C:\Users\victo\AppData\Local\Temp\ipykernel_31776\2309299637.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.agg([sum, min])
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupos = df_final.groupby('REGIÃO')
grupos

# %%
grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_31776\3199437311.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# C:\Users\victo\AppData\Local\Temp\ipykernel_31776\3199437311.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.226  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# ## Ordenação

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %%
notas.sort_values(by='nota_final', ascending=False)
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 3  Alice     20        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True])
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True], inplace=True)

# %%
notas
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# ## Exercícios

# %%
df_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
df_final.query('ANO != 2019')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# ...

# %%
df = df_final.query('ANO != 2019')

# %%
df
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ### Qual a quantidade de registros de cada Produto em cada região?

# %%
grupos = df.groupby('PRODUTO')
grupos

# %%
grupos['REGIÃO'].value_counts().to_frame()
# Out:
#                                count
# PRODUTO          REGIÃO
# ETANOL HIDRATADO NORDESTE       6821
#                  NORTE          5021
#                  SUDESTE        3039
#                  CENTRO OESTE   3022
#                  SUL            2278
# GASOLINA COMUM   NORDESTE       6838
#                  NORTE          5289
#                  SUDESTE        3040
#                  CENTRO OESTE   3034
#                  SUL            2279
# GLP              NORDESTE       6185
#                  NORTE          5152
#                  SUDESTE        3037
#                  CENTRO OESTE   2998
#                  SUL            2268
# GNV              NORDESTE       5030
#                  SUDESTE        2772
#                  SUL            1847
#                  CENTRO OESTE    825
#                  NORTE           233
# ÓLEO DIESEL      NORDESTE       6836
#                  NORTE          5290
#                  SUDESTE        3040
# ...

# %% [markdown]
# ### Como o spreços da Gasolina Comum em São Paulo Variaram em 2018?

# %%
gasolina_sp_2018 = df.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_sp_2018.head()
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92610   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92755   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92901   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92319                          1641              R$/l                3.988
# 92465                          1648              R$/l                4.002
# 92610                          1648              R$/l                4.006
# 92755                          1644              R$/l                4.019
# 92901                          1646              R$/l                4.004
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %%
gasolina_sp_2018.shape
# Out:
# (52, 20)

# %%
gasolina_sp_2018.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                     52.000000            52.000000
# mean                    1610.211538             4.202769
# std                      213.627432             0.180672
# min                      102.000000             3.970000
# 25%                     1639.000000             4.008000
# 50%                     1642.000000             4.202000
# 75%                     1644.000000             4.336250
# max                     1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# min                 0.150000              3.369000              4.499000
# 25%                 0.159750              3.499000              4.899000
# ...

# %%
gasolina_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %% [markdown]
# ### Como o spreços da gasolina comum e do etanol em São Paulo variaram em 2018?

# %%
df.query('(PRODUTO == "GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO") and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...            ...         ...      ...        ...               ...
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
lista_de_estados = ["GASOLINA COMUM", "ETANOL HIDRATADO"]
df.query('PRODUTO in @lista_de_estados and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...            ...         ...      ...        ...               ...
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
gasolina_etanol_sp_2018 = df.query('PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"] and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_etanol_sp_2018
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...            ...         ...      ...        ...               ...
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
gasolina_etanol_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count           104.000000
# mean              3.457337
# std               0.766239
# min               2.393000
# 25%               2.726000
# 50%               3.431000
# 75%               4.199000
# max               4.512000

# %%
gasolina_etanol_sp_2018.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512
